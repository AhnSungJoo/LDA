# %%
from sklearn.datasets import load_files
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import lda
import numpy as np
import mglearn
import matplotlib.pyplot as plt
import re

# %%
docs = open("data/thesis/news2.txt").read()
docs2 = open("data/thesis/news.txt").read()

# %%
documents = [docs,docs2]

# %%
documents[0]
# Out:
# 'West Palm Beach, Florida (CNN)President Donald Trump offered a bullish view on Wednesday of his planned talks with North Korean despot Kim Jong Un, insisting he\'s positioned to accomplish what his predecessors could not.\n\nStill, he maintained he\'d be willing to stand up and leave the highly anticipated summit should the meeting fall short of his expectations.\n"If we don\'t think it\'s going to be successful, we won\'t have it," the President said, standing alongside his Japanese counterpart at Trump\'s oceanfront Mar-a-Lago estate here. "If the meeting when I\'m there isn\'t fruitful, I will respectfully leave the meeting."\nSponsor Content\nDay 2 highlights from the world\'s biggest mobile showcase\nA sizzling start-up and UK tech wizards boldly go forth in the fields of data and Li-Fi.\nContent provided by the UK’s Department for International Trade \n"I like always remaining flexible," Trump said. "We\'ll remain flexible here."\nTrump also maintained that his negotiating position with Pyongyang remains stronger than ever.\n"We\'ve never been in a position like this with that regime, whether it\'s father, grandfather or son," he said.\nTrump says 5 locations are being considered for Kim Jong Un meeting\nTrump says 5 locations are being considered for Kim Jong Un meeting\nTrump, who unexpectedly agreed to the Kim talks last month, has pressed forward with his plans, despite concerns from regional allies such as Japanese Prime Minister Shinzo Abe, who arrived in Florida this week to warn Trump that past US talks with North Korea have failed.\nThe two men conferred about the matter Tuesday alongside top national security aides. Talks on Wednesday focused on trade, including the possibility of exempting Japan from new US tariffs on steel and aluminum imports.\nIn between, Trump and Abe enjoyed a nearly five-hour round of golf at the nearby Trump International Golf Club.\nBoth men put forward displays of bonhomie during their extensive time together. Abe routinely referred to the President as "Donald," while Trump expounded on the friendship he has developed with the Japanese leader. They strolled the Mar-a-Lago croquet lawn with their wives before dinner Tuesday.\nBut tensions were visible. During remarks ahead of Wednesday\'s trade talks, Trump delivered a stern warning about unfair economic practices and vowed to stand up for American workers. And he paid little heed to Abe\'s warnings about North Korea -- instead indicating that preparations for talks are moving forward rapidly.\nPlay Video\n\nTrump: US has massive trade deficit with Japan 02:18\n"Hopefully that meeting will be a success and we are looking forward to it," Trump said at the news conference. "We will be doing everything possible to make it a worldwide success."\nHe did offer some concessions to Abe. He vowed to raise the issue of abducted Japanese citizens during his planned summit with Kim, a key request of Abe\'s.\n"Abduction is a very important issue for me because it\'s very important for your Prime Minister," Trump said in Florida.\nAbe, meanwhile, said he told Trump this week that North Korea wouldn\'t be rewarded simply for opening dialogue with the United States.\n"Maximum pressure should be maintained," Abe said at Mar-a-Lago. "President Trump and I were in full agreement."\nAs the two men sat for dinner Tuesday, it was revealed that Mike Pompeo, Trump\'s CIA director and pick for secretary of state, had traveled to North Korea for preliminary talks with Kim early this month. And Trump had said earlier in the evening that officials had identified five possible venues for the summit.\nThe President has stressed that he\'ll focus on denuclearization in his talks with Kim. But Abe has worked to gain a commitment that missile testing will also be on the agenda. Intermediate range missiles test-launched by North Korea have landed in the waters off Japan.'

# %%
stoplist = set('for a of the and to in'.split())

# %%
texts = [[word for word in document.lower().split() if word not in stoplist] for document in documents]

# %%
from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

# %%
texts = [[token for token in text if frequency[token] > 1] for text in texts]

# %%
from pprint import pprint

# %%
pprint(texts)
# Out:
# [['west',
#   'florida',
#   'donald',
#   'trump',
#   'view',
#   'on',
#   'wednesday',
#   'his',
#   'planned',
#   'talks',
#   'with',
#   'north',
#   'kim',
#   'jong',
#   'what',
#   'his',
#   'could',
#   'he',
#   'maintained',
#   'be',
#   'stand',
#   'up',
#   'leave',
#   'highly',
#   'anticipated',
#   'summit',
#   'should',
#   'meeting',
#   'fall',
#   'short',
#   'his',
#   '"if',
#   'we',
#   "it's",
#   'going',
#   'be',
#   'we',
#   'have',
#   'it,"',
#   'president',
#   'alongside',
#   'his',
#   'japanese',
#   'at',
#   "trump's",
#   'mar-a-lago',
#   '"if',
#   'meeting',
#   'when',
#   'there',
#   "isn't",
#   'i',
#   'will',
#   'leave',
#   'content',
#   'from',
#   'go',
#   'content',
#   'by',
#   'international',
#   'trade',
#   '"i',
#   'like',
#   'trump',
#   'said.',
#   'trump',
#   'also',
#   'maintained',
#   'that',
#   'his',
#   'position',
#   'with',
#   'than',
#   'been',
#   'position',
#   'like',
#   'this',
#   'with',
#   'that',
#   'whether',
#   "it's",
#   'or',
#   'he',
#   'said.',
#   'trump',
#   'says',
#   '5',
#   'locations',
#   'are',
#   'being',
#   'considered',
#   'kim',
#   'jong',
#   'un',
#   'meeting',
#   'trump',
#   'says',
#   '5',
#   'locations',
#   'are',
#   'being',
#   'considered',
#   'kim',
#   'jong',
#   'un',
#   'meeting',
#   'trump,',
#   'who',
#   'kim',
#   'talks',
#   'last',
#   'has',
#   'forward',
#   'with',
#   'his',
#   'from',
#   'such',
#   'as',
#   'japanese',
#   'prime',
#   'abe,',
#   'who',
#   'florida',
#   'this',
#   'week',
#   'trump',
#   'that',
#   'us',
#   'talks',
#   'with',
#   'north',
#   'korea',
#   'have',
#   'two',
#   'men',
#   'about',
#   'matter',
#   'tuesday',
#   'alongside',
#   'top',
#   'national',
#   'security',
#   'talks',
#   'on',
#   'wednesday',
#   'focused',
#   'on',
#   'including',
#   'japan',
#   'from',
#   'new',
#   'us',
#   'on',
#   'trump',
#   'abe',
#   'golf',
#   'at',
#   'trump',
#   'international',
#   'golf',
#   'men',
#   'put',
#   'forward',
#   'during',
#   'their',
#   'time',
#   'abe',
#   'president',
#   'as',
#   'while',
#   'trump',
#   'on',
#   'he',
#   'has',
#   'with',
#   'japanese',
#   'they',
#   'mar-a-lago',
#   'with',
#   'their',
#   'dinner',
#   'but',
#   'were',
#   'during',
#   'trade',
#   'trump',
#   'about',
#   'economic',
#   'vowed',
#   'stand',
#   'up',
#   'american',
#   'he',
#   'paid',
#   'little',
#   'about',
#   'north',
#   'korea',
#   '--',
#   'that',
#   'talks',
#   'are',
#   'forward',
#   'play',
#   'video',
#   'trump:',
#   'us',
#   'has',
#   'trade',
#   'with',
#   'japan',
#   'that',
#   'meeting',
#   'will',
#   'be',
#   'we',
#   'are',
#   'forward',
#   'it,"',
#   'trump',
#   'said',
#   'at',
#   'news',
#   'will',
#   'be',
#   'possible',
#   'it',
#   'he',
#   'did',
#   'offer',
#   'some',
#   'he',
#   'vowed',
#   'issue',
#   'japanese',
#   'during',
#   'his',
#   'planned',
#   'summit',
#   'with',
#   'is',
#   'very',
#   'important',
#   'issue',
#   "it's",
#   'very',
#   'important',
#   'prime',
#   'trump',
#   'said',
#   'abe,',
#   'said',
#   'he',
#   'told',
#   'trump',
#   'this',
#   'week',
#   'that',
#   'north',
#   'korea',
#   'be',
#   'with',
#   'united',
#   'pressure',
#   'should',
#   'be',
#   'abe',
#   'said',
#   'at',
#   'trump',
#   'i',
#   'were',
#   'as',
#   'two',
#   'men',
#   'dinner',
#   'it',
#   'was',
#   'revealed',
#   'that',
#   "trump's",
#   'director',
#   'had',
#   'north',
#   'korea',
#   'talks',
#   'with',
#   'kim',
#   'this',
#   'trump',
#   'had',
#   'said',
#   'that',
#   'officials',
#   'had',
#   'possible',
#   'president',
#   'has',
#   'that',
#   'on',
#   'his',
#   'talks',
#   'with',
#   'but',
#   'abe',
#   'has',
#   'that',
#   'will',
#   'also',
#   'be',
#   'on',
#   'by',
#   'north',
#   'korea',
#   'have',
#   'off'],
#  ['is',
#   'nothing',
#   'than',
#   'most',
#   'president',
#   'modern',
#   'james',
#   'comey',
#   'on',
#   'into',
#   'white',
#   'just',
#   'after',
#   '5',
#   'on',
#   'thursday,',
#   'as',
#   'leaks',
#   'fbi',
#   "director's",
#   'new',
#   'book',
#   'obama',
#   'reassured',
#   'comey',
#   'after',
#   'election',
#   'amid',
#   'email',
#   'investigation',
#   'controversy',
#   'obama',
#   'reassured',
#   'comey',
#   'after',
#   'election',
#   'amid',
#   'email',
#   'investigation',
#   'controversy',
#   'that',
#   'is',
#   'comey',
#   'his',
#   'his',
#   'by',
#   'president',
#   'donald',
#   'trump',
#   'last',
#   'when',
#   'it',
#   'it',
#   'was',
#   'president.',
#   'he',
#   'trump',
#   'as',
#   'liar',
#   'who',
#   'is',
#   'his',
#   'who',
#   'is',
#   'about',
#   'his',
#   'about',
#   'russian',
#   'assault',
#   'on',
#   'american',
#   'president',
#   'personal',
#   'comey',
#   "trump's",
#   'said',
#   'his',
#   'white',
#   'his',
#   'from',
#   'but',
#   'comey',
#   "isn't",
#   'just',
#   "trump's",
#   'he',
#   'is',
#   'on',
#   'more',
#   'his',
#   'book',
#   'is',
#   'about',
#   'threat',
#   'from',
#   'president',
#   'who',
#   'loyalty',
#   'has',
#   'only',
#   'no',
#   'like',
#   'an',
#   'fbi',
#   'director',
#   'former',
#   'trump',
#   'economic',
#   'adviser',
#   'said',
#   'on',
#   'cnn',
#   'book',
#   'news',
#   'about',
#   "comey's",
#   'highly',
#   'anticipated',
#   'his',
#   'time',
#   'trump',
#   'one',
#   'book,',
#   'comey',
#   'said',
#   'with',
#   'trump',
#   'his',
#   'days',
#   'with',
#   'their',
#   'loyalty',
#   'about',
#   'all',
#   'service',
#   'some',
#   'loyalty',
#   'that',
#   'put',
#   'above',
#   'above',
#   'is',
#   'now',
#   'is',
#   'not',
#   'it',
#   'is',
#   'not',
#   'it',
#   'is',
#   'not',
#   'he',
#   'that',
#   'seems',
#   'with',
#   'presidency.',
#   'official:',
#   'trump',
#   'expected',
#   'pardon',
#   'scooter',
#   'libby',
#   'official:',
#   'trump',
#   'expected',
#   'pardon',
#   'scooter',
#   'libby',
#   'all',
#   'are',
#   'by',
#   'former',
#   'that',
#   'their',
#   'west',
#   'george',
#   'clinton',
#   'all',
#   'by',
#   'yet',
#   'no',
#   'chief',
#   'modern',
#   'has',
#   'had',
#   'on',
#   'trump',
#   'by',
#   'comey,',
#   'who',
#   'that',
#   'president',
#   'fbi',
#   'as',
#   'personal',
#   'service',
#   'do',
#   'his',
#   'how',
#   'will',
#   'trump',
#   'most',
#   'question',
#   'now',
#   'is',
#   'how',
#   'trump,',
#   'who',
#   'over',
#   'on',
#   'his',
#   'will',
#   'former',
#   'fbi',
#   "director's",
#   'his',
#   'presidency.',
#   'by',
#   'legal',
#   'with',
#   'life',
#   'on',
#   'whether',
#   'trump',
#   'is',
#   'political',
#   'pressure',
#   'that',
#   'may',
#   'not',
#   'be',
#   'seems',
#   'sure',
#   'over',
#   'on',
#   'news',
#   'president',
#   'just',
#   'on',
#   'thursday,',
#   'it',
#   'was',
#   'reported',
#   'that',
#   'national',
#   'had',
#   'paid',
#   'off',
#   'at',
#   'one',
#   'his',
#   'that',
#   'president',
#   'had',
#   'an',
#   'cnn',
#   'has',
#   'neither',
#   'story',
#   'nor',
#   'but',
#   'if',
#   'it',
#   'into',
#   'people',
#   "trump's",
#   'yet',
#   'with',
#   'matter',
#   'said',
#   'that',
#   'trump',
#   'attorney',
#   'michael',
#   'made',
#   'his',
#   'likely',
#   'have',
#   'been',
#   'up',
#   'fbi',
#   'monday',
#   'on',
#   'attorney',
#   'hotel',
#   "cnn's",
#   'reported',
#   'that',
#   'president',
#   'had',
#   'only',
#   'just',
#   'off',
#   'after',
#   'which',
#   'resulted',
#   'from',
#   'new',
#   'from',
#   'special',
#   'counsel',
#   'but',
#   'news',
#   'leaks',
#   'was',
#   'likely',
#   'trump',
#   'up',
#   'all',
#   'over',
#   'there',
#   'are',
#   'people',
#   'he',
#   'more',
#   'than',
#   'an',
#   'interview',
#   'last',
#   'trump',
#   'former',
#   'fbi',
#   'chief',
#   'as',
#   'as',
#   'as',
#   'monday',
#   'president',
#   'comey',
#   'liar',
#   'said',
#   'he',
#   'had',
#   'been',
#   'right',
#   'him.',
#   'trump',
#   'has',
#   'made',
#   'no',
#   'his',
#   'view',
#   'comey',
#   'as',
#   'him.',
#   'like',
#   'over',
#   'book',
#   'by',
#   'michael',
#   'this',
#   'trump',
#   'will',
#   'not',
#   'were',
#   'just',
#   'week',
#   'trump,',
#   'as',
#   'comey',
#   'is',
#   'about',
#   'on',
#   'media',
#   'with',
#   'an',
#   'interview',
#   'with',
#   'george',
#   'on',
#   'on',
#   "cnn's",
#   'will',
#   'down',
#   'with',
#   'former',
#   'fbi',
#   'director',
#   "it's",
#   'not',
#   'that',
#   'national',
#   'on',
#   'revealed',
#   'by',
#   "cnn's",
#   'on',
#   'thursday,',
#   'will',
#   'be',
#   'claims',
#   'book.',
#   "comey's",
#   'about',
#   'including',
#   'claim',
#   'that',
#   'trump',
#   'hotel',
#   '--',
#   'claims',
#   'that',
#   'have',
#   'not',
#   'been',
#   '--',
#   'could',
#   'claims',
#   'that',
#   'he',
#   'is',
#   'going',
#   'tabloid',
#   'just',
#   'play',
#   'video',
#   'tabloid',
#   'paid',
#   'story',
#   'book',
#   'have',
#   'life',
#   'book',
#   'is',
#   'sure',
#   'have',
#   'political',
#   'legal',
#   'on',
#   'tuesday',
#   'is',
#   'over',
#   'russian',
#   'election',
#   'book,',
#   'comey',
#   'being',
#   'that',
#   'neither',
#   'trump',
#   'nor',
#   'his',
#   'asked',
#   'top',
#   'officials',
#   'at',
#   'meeting',
#   'trump',
#   'what',
#   'russian',
#   'threat',
#   'might',
#   'nor',
#   'did',
#   'they',
#   'how',
#   'united',
#   'might',
#   'that',
#   'book',
#   'they',
#   'focused',
#   'on',
#   'they',
#   'could',
#   'what',
#   'just',
#   'told',
#   "comey's",
#   'assault',
#   'could',
#   'play',
#   'into',
#   "trump's",
#   'as',
#   'he',
#   'whether',
#   'attorney',
#   'general',
#   'as',
#   'down',
#   'james',
#   'comey',
#   'just',
#   'went',
#   'war',
#   'with',
#   'donald',
#   'trump',
#   'james',
#   'comey',
#   'just',
#   'went',
#   'war',
#   'with',
#   'donald',
#   'trump',
#   'it',
#   'will',
#   'offer',
#   'who',
#   'will',
#   'that',
#   'trump',
#   'or',
#   'be',
#   'president.',
#   'but',
#   'little',
#   'it',
#   'will',
#   "trump's",
#   'on',
#   'his',
#   'political',
#   'which',
#   'view',
#   'such',
#   'media',
#   'as',
#   'more',
#   'that',
#   'is',
#   'against',
#   'book',
#   'that',
#   'comey,',
#   'who',
#   'has',
#   'will',
#   'be',
#   'as',
#   'special',
#   'counsel',
#   'whether',
#   'president',
#   'book,',
#   'comey',
#   'his',
#   'claim',
#   'that',
#   'trump',
#   'asked',
#   'if',
#   'he',
#   'could',
#   'go',
#   'on',
#   'former',
#   'national',
#   'security',
#   'adviser',
#   'michael',
#   'which',
#   'he',
#   'revealed',
#   'last',
#   'but',
#   'he',
#   'short',
#   'an',
#   'against',
#   'trump:',
#   '"i',
#   'have',
#   'one',
#   'on',
#   'i',
#   'which',
#   'while',
#   'may',
#   'fall',
#   'short',
#   'being',
#   'from',
#   'book',
#   'also',
#   'just',
#   'how',
#   "comey's",
#   'resulted',
#   'fbi',
#   'being',
#   'into',
#   'likely',
#   'be',
#   'by',
#   'days',
#   'controversy',
#   'over',
#   'his',
#   'book.',
#   'those',
#   'who',
#   'find',
#   'comey',
#   'with',
#   'his',
#   'may',
#   'also',
#   'find',
#   'their',
#   'book.',
#   'one',
#   'he',
#   'obama',
#   'attorney',
#   'general',
#   'as',
#   'clinton',
#   'email',
#   'which',
#   'he',
#   'was',
#   'by',
#   'comey',
#   'also',
#   'that',
#   'he',
#   'was',
#   'told',
#   'by',
#   'obama',
#   'after',
#   'election',
#   'that',
#   'nothing',
#   'that',
#   'had',
#   'had',
#   'question',
#   'his',
#   'were',
#   'those',
#   'i',
#   'he',
#   '"i',
#   'he',
#   'that',
#   'he',
#   'told',
#   'just',
#   'do',
#   'right']]

# %%
def preprocessing(content):
    content = re.sub('\\xa0', '', content)
    content = re.sub('\\n', '', content)
    content = re.sub('\\\\xa0', '', content)
    content = re.sub('\\\\n', '', content)
    content = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@#$%&\\\=\(\'\")]', '', content)
    content = ' '.join(content.split())
                     
    return content

docs_ko=preprocessing(docs)

# %% [markdown]
# ## 전처리과정

# %%
docs_ko = [docs_ko]

# %% [markdown]
# ## list 변환

# %%
print(docs_ko)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
vect = CountVectorizer(max_features=100,stop_words="english").fit(docs_ko)
X = vect.fit_transform(docs_ko)

# %%
model = lda.LDA(n_topics=20, n_iter=1500, random_state=1)

# %%
model.fit(X)
# Out:
# INFO:lda:n_documents: 1
# INFO:lda:vocab_size: 100
# INFO:lda:n_words: 156537
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 1500
# INFO:lda:<0> log likelihood: -1139676
# INFO:lda:<10> log likelihood: -1100049
# INFO:lda:<20> log likelihood: -1065824
# INFO:lda:<30> log likelihood: -1036405
# INFO:lda:<40> log likelihood: -1011233
# INFO:lda:<50> log likelihood: -990975
# INFO:lda:<60> log likelihood: -969200
# INFO:lda:<70> log likelihood: -951836
# INFO:lda:<80> log likelihood: -936328
# INFO:lda:<90> log likelihood: -921856
# INFO:lda:<100> log likelihood: -907221
# INFO:lda:<110> log likelihood: -892683
# INFO:lda:<120> log likelihood: -880148
# INFO:lda:<130> log likelihood: -872359
# INFO:lda:<140> log likelihood: -862508
# INFO:lda:<150> log likelihood: -854593
# INFO:lda:<160> log likelihood: -847932
# INFO:lda:<170> log likelihood: -838209
# INFO:lda:<180> log likelihood: -831416
# INFO:lda:<190> log likelihood: -825171
# INFO:lda:<200> log likelihood: -824519
# INFO:lda:<210> log likelihood: -820831
# INFO:lda:<220> log likelihood: -816788
# INFO:lda:<230> log likelihood: -811807
# INFO:lda:<240> log likelihood: -808022
# INFO:lda:<250> log likelihood: -802801
# INFO:lda:<260> log likelihood: -797605
# INFO:lda:<270> log likelihood: -794800
# INFO:lda:<280> log likelihood: -791389
# INFO:lda:<290> log likelihood: -788989
# INFO:lda:<300> log likelihood: -788539
# INFO:lda:<310> log likelihood: -784756
# INFO:lda:<320> log likelihood: -783372
# INFO:lda:<330> log likelihood: -781044
# INFO:lda:<340> log likelihood: -780011
# INFO:lda:<350> log likelihood: -777674
# INFO:lda:<360> log likelihood: -775221
# INFO:lda:<370> log likelihood: -774909
# INFO:lda:<380> log likelihood: -773361
# INFO:lda:<390> log likelihood: -772802
# INFO:lda:<400> log likelihood: -772372
# INFO:lda:<410> log likelihood: -771032
# INFO:lda:<420> log likelihood: -769372
# INFO:lda:<430> log likelihood: -769517
# INFO:lda:<440> log likelihood: -769078
# INFO:lda:<450> log likelihood: -767142
# INFO:lda:<460> log likelihood: -765212
# INFO:lda:<470> log likelihood: -766166
# INFO:lda:<480> log likelihood: -766362
# INFO:lda:<490> log likelihood: -765192
# INFO:lda:<500> log likelihood: -765519
# INFO:lda:<510> log likelihood: -763790
# INFO:lda:<520> log likelihood: -762170
# INFO:lda:<530> log likelihood: -760961
# INFO:lda:<540> log likelihood: -761240
# INFO:lda:<550> log likelihood: -761848
# INFO:lda:<560> log likelihood: -763588
# INFO:lda:<570> log likelihood: -761828
# INFO:lda:<580> log likelihood: -760096
# INFO:lda:<590> log likelihood: -759254
# INFO:lda:<600> log likelihood: -758631
# INFO:lda:<610> log likelihood: -757793
# INFO:lda:<620> log likelihood: -757357
# INFO:lda:<630> log likelihood: -757559
# INFO:lda:<640> log likelihood: -758203
# INFO:lda:<650> log likelihood: -757605
# INFO:lda:<660> log likelihood: -757646
# INFO:lda:<670> log likelihood: -756522
# INFO:lda:<680> log likelihood: -754948
# INFO:lda:<690> log likelihood: -754482
# INFO:lda:<700> log likelihood: -754374
# INFO:lda:<710> log likelihood: -755852
# INFO:lda:<720> log likelihood: -758441
# INFO:lda:<730> log likelihood: -757285
# INFO:lda:<740> log likelihood: -756925
# INFO:lda:<750> log likelihood: -757778
# INFO:lda:<760> log likelihood: -757018
# INFO:lda:<770> log likelihood: -756260
# INFO:lda:<780> log likelihood: -757495
# INFO:lda:<790> log likelihood: -757523
# INFO:lda:<800> log likelihood: -755309
# INFO:lda:<810> log likelihood: -753855
# INFO:lda:<820> log likelihood: -753666
# INFO:lda:<830> log likelihood: -754112
# INFO:lda:<840> log likelihood: -754438
# INFO:lda:<850> log likelihood: -753568
# INFO:lda:<860> log likelihood: -753259
# INFO:lda:<870> log likelihood: -754022
# INFO:lda:<880> log likelihood: -752626
# INFO:lda:<890> log likelihood: -752611
# INFO:lda:<900> log likelihood: -751914
# INFO:lda:<910> log likelihood: -751434
# INFO:lda:<920> log likelihood: -754112
# INFO:lda:<930> log likelihood: -753893
# INFO:lda:<940> log likelihood: -752481
# INFO:lda:<950> log likelihood: -752869
# INFO:lda:<960> log likelihood: -752971
# INFO:lda:<970> log likelihood: -752123
# INFO:lda:<980> log likelihood: -753457
# INFO:lda:<990> log likelihood: -753842
# INFO:lda:<1000> log likelihood: -754260
# INFO:lda:<1010> log likelihood: -752956
# INFO:lda:<1020> log likelihood: -752877
# INFO:lda:<1030> log likelihood: -753333
# INFO:lda:<1040> log likelihood: -753394
# INFO:lda:<1050> log likelihood: -753454
# INFO:lda:<1060> log likelihood: -755144
# INFO:lda:<1070> log likelihood: -754935
# INFO:lda:<1080> log likelihood: -755002
# INFO:lda:<1090> log likelihood: -755400
# INFO:lda:<1100> log likelihood: -756323
# INFO:lda:<1110> log likelihood: -756167
# INFO:lda:<1120> log likelihood: -754921
# INFO:lda:<1130> log likelihood: -756293
# INFO:lda:<1140> log likelihood: -755324
# INFO:lda:<1150> log likelihood: -757334
# INFO:lda:<1160> log likelihood: -759093
# INFO:lda:<1170> log likelihood: -758178
# INFO:lda:<1180> log likelihood: -758261
# INFO:lda:<1190> log likelihood: -759734
# INFO:lda:<1200> log likelihood: -759276
# INFO:lda:<1210> log likelihood: -757539
# INFO:lda:<1220> log likelihood: -757710
# INFO:lda:<1230> log likelihood: -757339
# INFO:lda:<1240> log likelihood: -759177
# INFO:lda:<1250> log likelihood: -758028
# INFO:lda:<1260> log likelihood: -758430
# INFO:lda:<1270> log likelihood: -760361
# INFO:lda:<1280> log likelihood: -760537
# INFO:lda:<1290> log likelihood: -760203
# INFO:lda:<1300> log likelihood: -758320
# INFO:lda:<1310> log likelihood: -758251
# INFO:lda:<1320> log likelihood: -758260
# INFO:lda:<1330> log likelihood: -758110
# INFO:lda:<1340> log likelihood: -757844
# INFO:lda:<1350> log likelihood: -755894
# INFO:lda:<1360> log likelihood: -755696
# INFO:lda:<1370> log likelihood: -756024
# INFO:lda:<1380> log likelihood: -757380
# INFO:lda:<1390> log likelihood: -758672
# INFO:lda:<1400> log likelihood: -759922
# INFO:lda:<1410> log likelihood: -759769
# INFO:lda:<1420> log likelihood: -759532
# INFO:lda:<1430> log likelihood: -760709
# INFO:lda:<1440> log likelihood: -760569
# INFO:lda:<1450> log likelihood: -760811
# INFO:lda:<1460> log likelihood: -759588
# INFO:lda:<1470> log likelihood: -761828
# INFO:lda:<1480> log likelihood: -761834
# INFO:lda:<1490> log likelihood: -761686
# INFO:lda:<1499> log likelihood: -759215

# %%
topic_test = model.transform(X)

# %%
for topics in topic_test:
    print("{}".format(topics))
# Out:
# [ 0.26480761  0.08775402  0.01251913  0.02002519  0.0173036   0.01088763
#   0.02029978  0.01019877  0.00423731  0.01070678  0.02386365  0.01564012
#   0.00788722  0.01633686  0.00814883  0.02308263  0.02669746  0.05688173
#   0.09201588  0.27070581]

# %% [markdown]
# ## stop_words 는 불용어를 제거시켜준다

# %% [markdown]
# ## data를 BOW형 으로 변환

# %%
lda = LatentDirichletAllocation(n_components=10, learning_method="online",
                               max_iter=25, random_state=0)
documents_topics = lda.fit_transform(X)

# %%
documents_topics
# Out:
# array([[  6.38852768e-07,   6.38847717e-07,   2.54777877e-01,
#           6.38901069e-07,   6.38937732e-07,   6.38943252e-07,
#           1.73611265e-01,   1.54235494e-01,   1.93782608e-01,
#           2.23589561e-01]])

# %% [markdown]
# ## lda 변환

# %%
print("lda.components_.shape: {}".format(lda.components_.shape))
# Out:
# lda.components_.shape: (10, 100)

# %%
sorting = np.argsort(lda.components_,axis=1)[:, ::-1]
feature_names = np.array(vect.get_feature_names())

# %% [markdown]
# ## 행의 특성을 내림차순으로 정렬
# ## Countervectorizer 객체에서 특성 이름 추출

# %%
mglearn.tools.print_topics(topics=range(10), feature_names=feature_names, sorting=sorting, topics_per_chunk=5, n_words=5)
# Out:
# topic 0       topic 1       topic 2       topic 3       topic 4
# --------      --------      --------      --------      --------
# 영화            영화            영화            영화            영화
# 정말            진짜            너무            정말            정말
# 너무            정말            정말            너무            너무
# 진짜            너무            진짜            진짜            진짜
# 그냥            그냥            이런            그냥            영화를
#
#
# topic 5       topic 6       topic 7       topic 8       topic 9
# --------      --------      --------      --------      --------
# 영화            영화            영화            영화            영화
# 정말            정말            정말            너무            너무
# 너무            너무            진짜            정말            진짜
# 진짜            진짜            너무            진짜            정말
# 그냥            영화를           그냥            이런            이런
